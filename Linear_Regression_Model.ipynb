# %% [markdown]
# <a href="https://colab.research.google.com/github/funnnkey/Data-Visualisation-project/blob/colab.project/Linear_Regression_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/bike_sales.txt')

# %%
df['Profit'] = df['Profit'].str.replace('$', '', regex=False)
df['Profit'] = df['Profit'].str.replace(' ', '', regex=False)
df['Profit'] = df['Profit'].str.replace(',', '', regex=False)

# %%
df['Cost'] = df['Cost'].str.replace('$', '', regex=False)
df['Cost'] = df['Cost'].str.replace(' ', '', regex=False)
df['Cost'] = df['Cost'].str.replace(',', '', regex=False)

# %%
df['Profit'] = pd.to_numeric(df['Profit'])
df['Cost'] = pd.to_numeric(df['Cost'])

# %%
df.head()
# Out:
#         Date     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# 0  12/1/2021  December  2021            39  Adults (35-64)               F
# 1  12/1/2021  December  2021            42  Adults (35-64)               M
# 2  12/1/2021  December  2021            36  Adults (35-64)               F
# 3  12/1/2021  December  2021            20     Youth (<25)               M
# 4  12/1/2021  December  2021            23     Youth (<25)               M
#
#           Country        State Product_Category  Order_Quantity  Profit  \
# 0   United States   California            Bikes               4  3988.0
# 1   United States   Washington            Bikes               3   232.0
# 2         Germany  Brandenburg            Bikes               2   792.0
# 3         Germany      Hamburg            Bikes               1   717.0
# 4  United Kingdom      England            Bikes               1  1264.0
#
#      Cost     Revenue
# 0  5008.0   $8,996.00
# 1  1032.0   $1,264.00
# ...

# %%
df.tail()
# Out:
#          Date     Month  Year  Customer_Age             Age_Group  \
# 6   12/1/2021  December  2021            28  Young Adults (25-34)
# 7   12/1/2021  December  2021            28  Young Adults (25-34)
# 8   12/1/2021  December  2021            31  Young Adults (25-34)
# 9   12/1/2021  December  2021            34  Young Adults (25-34)
# 10  12/1/2021  December  2021            44        Adults (35-64)
#
#    Customer_Gender         Country            State Product_Category  \
# 6                F       Australia  New South Wales            Bikes
# 7                F   United States       California            Bikes
# 8                F       Australia  South Australia            Bikes
# 9                M       Australia  New South Wales            Bikes
# 10               M  United Kingdom          England            Bikes
#
#     Order_Quantity  Profit    Cost     Revenue
# 6                1   570.0  1555.0   $2,125.00
# 7                1   185.0   344.0     $529.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              11 non-null     object
#  1   Month             11 non-null     object
#  2   Year              11 non-null     int64
#  3   Customer_Age      11 non-null     int64
#  4   Age_Group         11 non-null     object
#  5   Customer_Gender   11 non-null     object
#  6   Country           11 non-null     object
#  7   State             11 non-null     object
#  8   Product_Category  11 non-null     object
#  9   Order_Quantity    11 non-null     int64
#  10  Profit            11 non-null     float64
#  11  Cost              11 non-null     float64
#  12   Revenue          11 non-null     object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 1.2+ KB

# %%
df.describe()
# Out:
#          Year  Customer_Age  Order_Quantity       Profit         Cost
# count    11.0     11.000000       11.000000    11.000000    11.000000
# mean   2021.0     31.636364        1.545455   903.545455  1609.818182
# std       0.0      8.065640        1.035725  1072.653846  1226.440771
# min    2021.0     20.000000        1.000000   185.000000   344.000000
# 25%    2021.0     25.500000        1.000000   391.000000  1057.500000
# 50%    2021.0     31.000000        1.000000   570.000000  1426.000000
# 75%    2021.0     37.500000        1.500000   876.500000  1555.000000
# max    2021.0     44.000000        4.000000  3988.000000  5008.000000

# %%
df.describe(include='all')
# Out:
#              Date     Month    Year  Customer_Age       Age_Group  \
# count          11        11    11.0     11.000000              11
# unique          1         1     NaN           NaN               3
# top     12/1/2021  December     NaN           NaN  Adults (35-64)
# freq           11        11     NaN           NaN               4
# mean          NaN       NaN  2021.0     31.636364             NaN
# std           NaN       NaN     0.0      8.065640             NaN
# min           NaN       NaN  2021.0     20.000000             NaN
# 25%           NaN       NaN  2021.0     25.500000             NaN
# 50%           NaN       NaN  2021.0     31.000000             NaN
# 75%           NaN       NaN  2021.0     37.500000             NaN
# max           NaN       NaN  2021.0     44.000000             NaN
#
#        Customer_Gender        Country       State Product_Category  \
# count               11             11          11               11
# ...

# %%
df.shape
# Out:
# (11, 13)

# %%
df.columns
# Out:
# Index(['Date', 'Month', 'Year', 'Customer_Age', 'Age_Group', 'Customer_Gender',
#        'Country', 'State', 'Product_Category', 'Order_Quantity', 'Profit',
#        'Cost', ' Revenue '],
#       dtype='object')

# %%
df['Profit']
# Out:
# 0     3988.0
# 1      232.0
# 2      792.0
# 3      717.0
# 4     1264.0
# 5      385.0
# 6      570.0
# 7      185.0
# 8      448.0
# 9      397.0
# 10     961.0
# Name: Profit, dtype: float64

# %%
df['Profit'].value_counts()
# Out:
# 3988.0    1
# 232.0     1
# 792.0     1
# 717.0     1
# 1264.0    1
# 385.0     1
# 570.0     1
# 185.0     1
# 448.0     1
# 397.0     1
# 961.0     1
# Name: Profit, dtype: int64

# %%
df.isna().sum()
# Out:
# Date                0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Order_Quantity      0
# Profit              0
# Cost                0
#  Revenue            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date                0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Order_Quantity      0
# Profit              0
# Cost                0
#  Revenue            0
# dtype: int64

# %%
y = df['Profit']
x = df[['Cost']]

# %%
df.shape
# Out:
# (11, 13)

# %%
x.shape
# Out:
# (11, 1)

# %%
y.shape
# Out:
# (11,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,train_size= 0.7,random_state=2529)
X_train
# Out:
#       Cost
# 6   1555.0
# 8   1555.0
# 10  1266.0
# 7    344.0
# 4   2171.0
# 2   1426.0
# 0   5008.0

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,train_size= 0.7,random_state=2529)
y_train
# Out:
# 6      570.0
# 8      448.0
# 10     961.0
# 7      185.0
# 4     1264.0
# 2      792.0
# 0     3988.0
# Name: Profit, dtype: float64

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((7, 1), (4, 1), (7,), (4,))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# -448.1214908915035

# %%
model.coef_
# Out:
# array([0.85139591])

# %%
y_pred = model.predict(X_test)

# %%
y_test
# Out:
# 5    385.0
# 3    717.0
# 9    397.0
# 1    232.0
# Name: Profit, dtype: float64

# %%
y_pred
# Out:
# array([158.92378949, 875.79914163, 473.9402744 , 430.51908323])

# %%
from sklearn.metrics import mean_absolute_percentage_error,mean_absolute_error,mean_squared_error
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.46454451064655505

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 165.08367744286426

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 30414.313143513493
